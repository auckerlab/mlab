# %% [markdown]
# <a href="https://colab.research.google.com/github/auckerlab/mlab/blob/main/BiLSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
print(torch.__version__)
# Out:
# 1.12.1+cu113

# %%
# !git clone https://github.com/Gxzzz/BiLSTM-CRF
# Out:
# Cloning into 'BiLSTM-CRF'...
# remote: Enumerating objects: 38, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 38 (delta 3), reused 1 (delta 1), pack-reused 28
# Unpacking objects: 100% (38/38), done.

# %%
# !pip install docopt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13723 sha256=9891b296521a0cfa0d762623e1fdd6cf28c09cef3688a07981e6ff11d0e098f3
#   Stored in directory: /root/.cache/pip/wheels/72/b0/3f/1d95f96ff986c7dfffe46ce2be4062f38ebd04b506c77c81b9
# Successfully built docopt
# ...

# %%
# !python ./BiLSTM-CRF/run.py train ./BiLSTM-CRF/data/train.txt ./BiLSTM-CRF/vocab/sent_vocab.json ./BiLSTM-CRF/vocab/tag_vocab.json --cuda
# Out:
# num of training examples: 40526
# num of development examples: 10132
# start training...
# log: epoch 1, iter 10, 13587.5 words/sec, avg_loss 100.082083, time 1.1 sec
# log: epoch 1, iter 20, 20224.8 words/sec, avg_loss 67.274557, time 0.7 sec
# log: epoch 1, iter 30, 19116.8 words/sec, avg_loss 57.058923, time 0.8 sec
# log: epoch 1, iter 40, 20455.5 words/sec, avg_loss 56.692452, time 0.7 sec
# log: epoch 1, iter 50, 18930.7 words/sec, avg_loss 52.247855, time 0.7 sec
# log: epoch 1, iter 60, 18202.5 words/sec, avg_loss 49.513604, time 0.7 sec
# log: epoch 1, iter 70, 19591.4 words/sec, avg_loss 51.516952, time 0.8 sec
# log: epoch 1, iter 80, 19678.5 words/sec, avg_loss 48.086707, time 0.7 sec
# log: epoch 1, iter 90, 19341.9 words/sec, avg_loss 46.742838, time 0.7 sec
# log: epoch 1, iter 100, 18929.1 words/sec, avg_loss 48.434463, time 0.8 sec
# log: epoch 1, iter 110, 19523.1 words/sec, avg_loss 43.975750, time 0.7 sec
# ...

# %%
# !sh BiLSTM-CRF/run.sh test
# Out:
# num of test samples: 4631
# Traceback (most recent call last):
#   File "BiLSTM-CRF/run.py", line 207, in <module>
#     main()
#   File "BiLSTM-CRF/run.py", line 203, in main
#     test(args)
#   File "BiLSTM-CRF/run.py", line 150, in test
#     model = bilstm_crf.BiLSTMCRF.load(args['MODEL'], device)
#   File "/content/BiLSTM-CRF/bilstm_crf.py", line 135, in load
#     params = torch.load(filepath, map_location=lambda storage, loc: storage)
#   File "/usr/local/lib/python3.7/dist-packages/torch/serialization.py", line 699, in load
#     with _open_file_like(f, 'rb') as opened_file:
#   File "/usr/local/lib/python3.7/dist-packages/torch/serialization.py", line 230, in _open_file_like
#     return _open_file(name_or_buffer, mode)
#   File "/usr/local/lib/python3.7/dist-packages/torch/serialization.py", line 211, in __init__
#     super(_open_file, self).__init__(open(name, mode))
# FileNotFoundError: [Errno 2] No such file or directory: './model/model.pth'
# ...
